# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariannly/EPIC_5_Tutorials/blob/main/Tutorials/tutorial_3/3_dendogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The Dendogram Method:
#
# - We will find clumps in simulated data.
#
# - To open the simulation dataset, we will use pyvista to open and view the results of an MHD simulation of an Orszag-Tang vortex, which generates turbulence.
#
# - pyvista: https://docs.pyvista.org/index.html
#
# ## Vortex simulation
#
# We will fetch the data files from a GitHub repository.

# %% [markdown]
# ### Download simulation data:

# %%
# Import libraries
from google.colab import drive

# %%
# Mount Google Drive
print("Mounting Google Drive...")
drive.mount('/content/drive')
# Out:
# Mounting Google Drive...
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/EPIC_V

# !ls -ltr
# Out:
# /content/drive/MyDrive/EPIC_V
# total 45966
# -rw------- 1 root root 43954909 Apr 13  2021 Online_Retail.csv
# -rw------- 1 root root  1150061 May 12 03:24 img.png
# -rw------- 1 root root  1958935 May 13 13:39 stage1.ipynb
# drwx------ 2 root root     4096 Jun 20 17:00 Stage2

# %%
import matplotlib.cbook as cbook

# %%
# Download the full simulation.
# !wget https://raw.githubusercontent.com/wbandabarragan/physics-teaching-data/main/2D-data/Orszag_Tang-MHD.zip
# Out:
# --2025-08-06 13:43:43--  https://raw.githubusercontent.com/wbandabarragan/physics-teaching-data/main/2D-data/Orszag_Tang-MHD.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84331313 (80M) [application/zip]
# Saving to: ‘Orszag_Tang-MHD.zip’
#
# Orszag_Tang-MHD.zip 100%[===================>]  80.42M  45.3MB/s    in 1.8s
#
# 2025-08-06 13:43:50 (45.3 MB/s) - ‘Orszag_Tang-MHD.zip’ saved [84331313/84331313]

# %% [markdown]
# ### Double check:

# %%
# !ls -ltr
# Out:
# total 128321
# -rw------- 1 root root 43954909 Apr 13  2021 Online_Retail.csv
# -rw------- 1 root root  1150061 May 12 03:24 img.png
# -rw------- 1 root root  1958935 May 13 13:39 stage1.ipynb
# drwx------ 2 root root     4096 Jun 20 17:00 Stage2
# -rw------- 1 root root 84331313 Aug  6 13:43 Orszag_Tang-MHD.zip

# %% [markdown]
# ### Unzip contents:

# %%
# !unzip -q Orszag_Tang-MHD.zip

# %% [markdown]
# ### Check simulation files:

# %%
# %cd Orszag_Tang-MHD
# Out:
# /content/drive/MyDrive/EPIC_V/Orszag_Tang-MHD

# %% [markdown]
# ### Double check that one of the files is there:

# %%
# !ls -ltr data.0030.vtk
# Out:
# -rw------- 1 root root 1575352 Aug 11  2022 data.0030.vtk

# %% [markdown]
# ### Install pyvista with pip:
#
# pyvista is not a standard library, pre-installed in the Google Colab server, so we need to add it manually.

# %%
# !pip install pyvista
# Out:
# Collecting pyvista
#   Downloading pyvista-0.46.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: matplotlib>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from pyvista) (3.10.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from pyvista) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from pyvista) (11.3.0)
# Requirement already satisfied: pooch in /usr/local/lib/python3.11/dist-packages (from pyvista) (1.8.2)
# Requirement already satisfied: scooby>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from pyvista) (0.10.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from pyvista) (4.14.1)
# Collecting vtk!=9.4.0 (from pyvista)
#   Downloading vtk-9.5.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.1->pyvista) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch->pyvista) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch->pyvista) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch->pyvista) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch->pyvista) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch->pyvista) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch->pyvista) (2025.7.14)
# Downloading pyvista-0.46.0-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 12.8 MB/s eta 0:00:00
# Downloading vtk-9.5.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (112.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.1/112.1 MB 7.7 MB/s eta 0:00:00
# Installing collected packages: vtk, pyvista
# Successfully installed pyvista-0.46.0 vtk-9.5.0

# %%
# Import libraries
import pyvista as pv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### File path:

# %%
# Define filename
file_name = "data.0030.vtk"

# We collect the data into a mesh
mesh_ot = pv.read(file_name)

# %% [markdown]
# ### Check metadata:

# %%
# Mesh information
#print(mesh_ot)
#print(mesh_ot.dimensions)
#print(mesh_ot.n_cells)
#print(mesh_ot.n_arrays)
#print(mesh_ot.array_names)
#print(mesh_ot.bounds)

# %%
# Density array
dens = pv.get_array(mesh_ot, "rho", preference = "cell")

# Array is flattened
print(dens.shape)
# Out:
# (65536,)

# %%
# Reshape the array
dens_2d = dens.reshape(mesh_ot.dimensions[1] - 1, mesh_ot.dimensions[0] - 1)

#print(dens_2d.shape)

# %%
# Figure

plt.figure(figsize=(7,7))

plt.imshow(dens_2d, cmap = "Blues")

plt.show()

# %% [markdown]
# ### Create meshgrid using metadata:

# %%
# Create coordinate vectors:
x = np.linspace(mesh_ot.bounds[0], mesh_ot.bounds[1], mesh_ot.dimensions[1] - 1)
y = np.linspace(mesh_ot.bounds[2], mesh_ot.bounds[3], mesh_ot.dimensions[0] - 1)

#print(x,y)
# Generate Grid
x_2d, y_2d = np.meshgrid(x, y)

# %%
# Figure
plt.figure(figsize=(7,6))

z = plt.pcolor(x_2d, y_2d, dens_2d, cmap = "Blues")

plt.colorbar(z)

plt.show()

# %% [markdown]
# ## Interactive maps

# %%
# Set number of VTK files
n_files = 60

# File name format
fname = "./data.{:04d}.vtk"

# Open empty lists/objects
densities = []

for t in range(n_files):
    # Get filename
    filename = fname.format(t)

    # Read mesh
    mesh_ot = pv.read(filename)

    # Get density array
    dens = pv.get_array(mesh_ot, "rho", preference="cell")

    # Reshape array: 1D -> 2D
    dens_2d = dens.reshape(mesh_ot.dimensions[0] - 1, mesh_ot.dimensions[1] - 1)

    # Append images to empty object
    densities.append(dens_2d)

# Animation function
def plot_frame(t):
    plt.figure(figsize=(6,5))

    plt.pcolor(x, y, densities[t], cmap="Blues", shading="auto")

    plt.colorbar(label="Density")

    plt.xlabel("x")
    plt.ylabel("y")

    plt.show()

# %%
from ipywidgets import interact, IntSlider

# %%
#Interactive slider (this may be slow)
#_ = interact(plot_frame, t=IntSlider(min=0, max=n_files - 1, step=1, value=0))

# %% [markdown]
# ## Clumpfinding with AstroDendro
#
# See: https://dendrograms.readthedocs.io/

# %%
# !pip install astrodendro
# Out:
# Collecting astrodendro
#   Downloading astrodendro-0.3.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: astropy>=5 in /usr/local/lib/python3.11/dist-packages (from astrodendro) (7.1.0)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.11/dist-packages (from astrodendro) (3.14.0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from astrodendro) (3.10.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from astrodendro) (2.0.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.11/dist-packages (from astropy>=5->astrodendro) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /usr/local/lib/python3.11/dist-packages (from astropy>=5->astrodendro) (0.2025.7.21.0.41.39)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy>=5->astrodendro) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy>=5->astrodendro) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->astrodendro) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->astrodendro) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->astrodendro) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->astrodendro) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->astrodendro) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->astrodendro) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->astrodendro) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->astrodendro) (1.17.0)
# Downloading astrodendro-0.3.1-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 3.0 MB/s eta 0:00:00
# Installing collected packages: astrodendro
# Successfully installed astrodendro-0.3.1

# %%
# Image plotting
plt.figure(figsize=(7,7))
plt.imshow(dens_2d, origin='lower', cmap='inferno')
plt.colorbar()
plt.title("Input Image")
plt.show()

# %%
# Import AstroDendro
from astrodendro import Dendrogram

# %%
# Get max/min values
print(np.min(dens_2d), np.max(dens_2d))
# Out:
# 0.6181619 4.9563127

# %%
# Thresholds
# ignore background/noise below this
min_value = 1.0

# structures must differ by at least this amount
min_delta = 0.1

# structures must cover at least 200 pixels
min_npix = 200


# Find hierarchical structures with clustering

d = Dendrogram.compute(dens_2d,min_value=min_value, min_delta=min_delta, min_npix=min_npix)

#print(f"# of structures: {len(d)}")
print(f"# of leaf nodes (clumps): {len(d.leaves)}")

# Combine all leaf masks
mask = np.zeros_like(dens_2d, dtype=bool)

# For loop
for structure in d.leaves:

  # If the pixel is 1 in either the current mask OR the new mask from, set that pixel to 1 in the mask.

  mask |= structure.get_mask()
# Out:
# # of leaf nodes (clumps): 30

# %%
# Combine all leaf masks
mask = np.zeros_like(dens_2d, dtype=bool)

# For loop
for structure in d.leaves:

  mask |= structure.get_mask()

# %%
# Plot results
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].imshow(dens_2d, cmap='viridis')

ax[1].imshow(mask, cmap='Reds')

plt.tight_layout()

plt.show()

# %%
# Plot figure
plt.figure(figsize=(8, 6))
z = plt.imshow(dens_2d, origin='lower', cmap='inferno')
plt.contour(mask, colors='white', linewidths=1)
plt.title("Dendrogram Leaf Clumps")
plt.colorbar(z)
plt.show()
